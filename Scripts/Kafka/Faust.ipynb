# %%
import faust

# Define a Faust application
app = faust.App('kafka-example', broker='kafka://3.17.23.28:9092')

# Define a Kafka topic
topic = app.topic('crypto')

# Define a Faust table to store results
results_table = app.Table('results_table', default=int)

# Define a Faust agent to process incoming messages
@app.agent(topic)
async def process_messages(messages):
    async for message in messages:
        # Process the incoming message
        value = message.value

        # Example processing: Count occurrences of each value
        print(value)

        # You can perform any other processing here
        
        # Print processed value (optional)

# Start the Faust application
if __name__ == '__main__':
    app.main()
# Out:
# Usage: ipykernel_launcher.py [OPTIONS] COMMAND [ARGS]...
# Try 'ipykernel_launcher.py --help' for help.
#
# Error: no such option: --f
# ---------------------------------------------------------------------------
# NoSuchOption                              Traceback (most recent call last)
# File c:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\click\core.py:781, in BaseCommand.main(self, args, prog_name, complete_var, standalone_mode, **extra)
#     780 try:
# --> 781     with self.make_context(prog_name, args, **extra) as ctx:
#     782         rv = self.invoke(ctx)
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\faust\cli\base.py:406, in _Group.make_context(self, info_name, args, app, parent, stdout, stderr, side_effects, **extra)
#     396 @no_type_check  # mypy bugs out on this
#     397 def make_context(self,
#     398                  info_name: str,
#    (...)
#     404                  side_effects: bool = True,
# ...

# %%
import faust

app=faust.App('demo-streaming',broker='kafka://3.17.23.28:9092')

# class Greeting(faust.Record,serializer='json'):
#     name:str
#     age:int

input_topic = app.topic('hcrypto', value_type='json')
aged_table = app.Table("major-count",key_type=str,value_type=str,partitions=1,default=int)


@app.agent(input_topic)
async def processor(stream):
    async for message in stream:
        if(message.age>30):
            aged_table[str(message.name)] = message.age
        print(aged_table.as_ansitable(title='Aged Tabled'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\mode\utils\objects.py:651, in cached_property.__get__(self, obj, type)
#     650 try:
# --> 651     return cast(RT, obj.__dict__[self.__name__])
#     652 except KeyError:
#
# KeyError: 'topics'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 10
#       5 input_topic = app.topic('crypto', value_type=json)
#       6 aged_table = app.Table("major-count",key_type=str,value_type=str,partitions=1,default=int)
#       9 @app.agent(input_topic)
# ---> 10 async def processor(stream):
#      11     async for message in stream:
#      12         if(message.age>30):
#
# ...
